# %% [markdown]
# ## SECTION 6 & 7: Numbers, Operators and Comments

# %% [markdown]
# ## NUMBERS AND MATH
#
# There are two main types of numbers
#
# 1. *Integer* (Whole Numbers)
# 2. *Floating Point* (Decimal Numbers)
#
#
#
# |Integer|Floating Point|
# |:----- |:-----|
# |4      |6.1               |
# |25      |1.3333333               |
#
#
# Commonly used math operators
#
# |Symbol|Name|
# |:-----:|:-----:|
# |+      |Addition               |
# |*   |Multiplication            |
# |/      |Division               |
# |**     |Exponentation               |
# |%      |Modulo              |
# |//     |Integer Division              |

# %% [markdown]
# ## VARIABLES AND DATA TYPES
#
# Variable Assignment
#
# Variable = A variable in Pythoin is like a variable in mathematics, it is a named symbol that holds a value.
#
# ```python
# X = 100
# Y = 50
# This_is_a_variable = 10
#
# print(X + Y + This_is_a_variable)
# ```
#
# Variable can be:
# 1. Assigned to other variables
# 2. reassigned at any time
# 3. assigned at the same time as other variables
#
# ```python
# python_is_awesome = 100
#
# just_another_var = python_is_awesome
#
# python_is_awesome = 1337
#
# ```

# %% [markdown]
# ## NAMING RESTRICTIONS
#
# Naming Restrictions
# In Python, you can name your variables whatever you want, with
# some restrictions:
# 1. Variables must start with a letter or underscore
# _cats 2cats
# 2. The rest of the name must consist of letters, numbers, or underscores
# cats2 hey@you
# 3. Names are case-sensitive
# CATS != Cats Cats != cats

# %% [markdown]
# ## NAMING CONVENTIONS
#
# Most Python programmers prefer to use standard style conventions
# when naming things:
#
# 1. Most variables should be snake_case (underscores between words)
# 2. Most variables should be also be lowercase, with some exceptions:
# CAPITAL_SNAKE_CASE usually refers to constants (e.g. PI = 3.14)
# UpperCamelCase usually refers to a class (more on that later)
# 3. Variables that start and end with two underscores (called "dunder"
# for double underscore) are supposed to be private or left alone
# __no_touchy__

# %% [markdown]
# ## DATA TYPES
#
# In any assigment the assigned value must alwayus be a valid data type.
#
# Python data types include:
#
# |Data Type|Description|
# |:----- |:-----|
# |bool    |True or False values               |
# |int      |an integer (1, 2, 3)             |
# |str      |(string) a sequence of Unicode characters, e.g. "Colt" or "程序设计"             |
# |list      |an ordered sequence of values of other data types, e.g. [1, 2, 3] or ["a","b","c"]             |
# |dict      |a collection of key: values, e.g. { "first_name": "Colt","last_name": "Steele" } |

# %% [markdown]
# ## DYNAMIC TYPING
#
# Python is highly flexible about reassigning variables to different types:
#
# ```python
# awesomeness = True
# print(awesomeness) # True
# awesomeness = "a dog"
# print(awesomeness) # a dog
# awesomeness = None
# print(awesomeness) # None
# awesomeness = 22 / 7
# print(awesomeness) # 3.142857142857143
# ```
#
# We call this dynamic typing, since variables can change types readily.
#
# Other languages, such as C++, are statically-typed, and variables are stuck
# with their originally-assigned type:
#
# ```python
# int not
# not
# awesomeness = 5;
# _
# awesomeness = "cool"; // !Error
# ```

# %% [markdown]
# ## Declaring Strings
#
# String literals in Python can be declared with either single or
# double quotes.
#
# ```python
# my_other_str = 'a hat'
# my_str = "a cat"
# ```
# Either one is perfectly fine; but make sure you stick to the
# same convention throughout the same file.

# %% [markdown]
# ## String Escape Characters
#
# In Python there are also "escape characters" which are "metacharacters" - they get interpreted by Python to do something special:
#
# ```python
# new_line = "hello \n world"
# _
# print(new_line)
# # hello
# # world
# ```
# All escape characters start with a backslash "\"
#
# ## String Concatenation
#
# Concatenation is combining multiple strings together. In Python you can do this simply with the "+" operator.
#
# ```python
#
# str_one = "your"
# str_two = "face"
#
# str_three = str_one +" "+ str_two
#
#  # your face
# ```
#
# ## Formatting Strings
#
# There are also several ways to format strings in Python to interpolate variables.
#
# The new way (new in Python 3.6+) => F-Strings
#
# ```python
#
# x = 10
# formatted = f"I've told you {x} times already!"
#
# ```
#
# ## Converting Data Types
#
# In string interpolation, data types are implicitly converted into string form (more on this later in OOP).
#
# You can also explicitly convert variables by using the name of the builtin type as a function (more on functions later):
#
# ```python
#
# decimal = 12.56345634534
# integer = int(decimal) # 12
#
# my_list = [1, 2, 3]
# my_list_as_a_tring = str(my_list) # "[1, 2, 3]"
#
# ```

# %% [markdown]
# ### RECAP
#
# - Python is a dynamically-typed language with more than half a dozen types
#
# - Python lets you assign and reassign variables at will to any of the types
#
# - There are some variable naming restrictions which are required and some naming guidelines which are recommended
